# %% [markdown]
# <a href="https://colab.research.google.com/github/nishee0521/Deep-Learning/blob/master/ConvolutionNeuralNetwork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
# importing important packages
from keras.models import Sequential
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Conv2D
from keras.layers import Dense

# %%
#initilizing the classifier
classifier=Sequential()

# %%
#adding the first Convolution layer
classifier.add(Conv2D(activation='relu', input_shape = (64, 64, 3), filters=32, kernel_size=(3,3)))

# %%
#maxpooling step
classifier.add(MaxPooling2D(pool_size=(2,2)))

# %%
#flattening step
classifier.add(Flatten())

# %%
#adding the fully connected layer
classifier.add(Dense(units = 128, activation='relu'))
#output layer
classifier.add(Dense(units = 1, activation='sigmoid'))

# %%
# !pip install pipupgrade

# %%
# !pipupgrade --verbose --latest --yes
# Out:
# 2020-04-22 06:31:10,355 | INFO | Executing command: /usr/local/bin/pip --version
# 2020-04-22 06:31:10,710 | INFO | Executing command: /usr/local/bin/pip3 --version
# 2020-04-22 06:31:11,040 | INFO | Executing command: /usr/local/bin/pip2 --version
# ...

# %%
classifier.compile(optimizer='adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

# %%
from keras.preprocessing.image import ImageDataGenerator
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip = True)

test_datagen = ImageDataGenerator(rescale=1./255)

# %%
training_set = train_datagen.flow_from_directory(
                                                  'training_set',
                                                  target_size=(64, 64),
                                                  batch_size=32,
                                                  class_mode='binary')
# Out:
# Found 8005 images belonging to 2 classes.

# %%
test_set = test_datagen.flow_from_directory(
                                                      'test_set',
                                                      target_size=(64, 64),
                                                      batch_size=32,
                                                      class_mode='binary')
# Out:
# Found 2000 images belonging to 2 classes.

# %%
classifier.fit_generator(
        training_set,
        steps_per_epoch=8005,
        epochs=25,
        validation_data=test_set,
        validation_steps=2000)
# Out:
# Epoch 1/25
# 8005/8005 [==============================] - 3469s 433ms/step - loss: 0.5458 - accuracy: 0.7144 - val_loss: 0.5306 - val_accuracy: 0.7368
# Epoch 2/25
# 8005/8005 [==============================] - 2423s 303ms/step - loss: 0.4378 - accuracy: 0.7922 - val_loss: 0.4635 - val_accuracy: 0.7300
# Epoch 3/25
# 8005/8005 [==============================] - 2485s 310ms/step - loss: 0.3763 - accuracy: 0.8290 - val_loss: 0.5101 - val_accuracy: 0.7254
# Epoch 4/25
# 4626/8005 [================>.............] - ETA: 15:21 - loss: 0.3411 - accuracy: 0.8476
